# %% [markdown]
# <a href="https://colab.research.google.com/github/Umang32/combine_csv/blob/main/combine_csv_files.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import glob
import os

# %%
path = '/content/files/'
all_files = glob.glob(path + "*.csv")

# %%
df = []

# %%
#for loop
li = pd.DataFrame()
i =1
for filename in all_files:
  if(i == 1):
    li = li.append(pd.read_csv(filename, index_col=None, header=4,sep=';'))
    i = 2
  else:
    # df = pd.read_csv(filename, index_col=None, header=5,sep=';')
    # li.append(df)
    li = li.append(pd.read_csv(filename, index_col=None, header=4,sep=';'))

# %%
li
# Out:
#       Bedrijf  Dossiernummer Vertrekdatum     Bedrag     Boekingstype  \
# 0           3         488532   30-12-2013     168,35           FLIGHT
# 1           3         488531   30-12-2013     168,35           FLIGHT
# 2           3         488530   30-12-2013     168,35           FLIGHT
# 3           3         488675     4-1-2014   3.889,39           FLIGHT
# 4           3         488597     8-1-2014     185,35           FLIGHT
# ...       ...            ...          ...        ...              ...
# 2407       33           2147     6-1-2014  18.749,44           FLIGHT
# 2408       33           2147     6-1-2014  10.747,35           FLIGHT
# 2409       33           2147     6-1-2014  18.716,44           FLIGHT
# 2410       33           2147   30-12-2013      544,7  REISVERZEKERING
# 2411       33           2147   30-12-2013      387,5          OVERIGE
#
#                  Product type Ticket nummer Ticket uitgifte datum PNR nummer  \
# ...

# %%
li.to_excel('/content/files/master_file.xlsx', index = False)
